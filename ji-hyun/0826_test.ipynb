# %%
import os
import json
import pandas as pd

# %% [markdown]
# 실력평가 001의 문항 IRT확인

# %%
path = 'C:/Users/klove/OneDrive/바탕 화면/학교 활동/창업동아리/mathdata/수학분야 학습자 역량 측정 데이터/Training/성취수준데이터셋_train/5학년/실력평가001/2_문항IRT'
l = os.listdir(path)
print(l)
# Out:
# ['A050000001_A050001001.json', 'A050000001_A050001002.json', 'A050000001_A050001003.json', 'A050000001_A050001004.json', 'A050000001_A050001005.json', 'A050000001_A050001006.json', 'A050000001_A050001007.json']

# %%
json_data2 = []
for i in l:
    with open(path+"/"+i,"r") as json_file:
        json_data2.append(json.load(json_file))

# %%
df = pd.DataFrame(json_data2)

# %%
df.head()
# Out:
#        testID assessmentItemID  difficultyLevel  discriminationLevel  \
# 0  A050000001       A050001001        -0.697606            35.359981
# 1  A050000001       A050001002        -1.280910            39.087825
# 2  A050000001       A050001003         0.016911             2.258198
# 3  A050000001       A050001004        -0.186766             1.947567
# 4  A050000001       A050001005         0.402467             4.070137
#
#      guessLevel knowledgeTag                   Timestamp
# 0  1.147400e-06         2620  2021-01-08 06:08:25.336946
# 1  3.631640e-02         2620  2021-01-08 06:08:25.336946
# 2  7.119000e-07         2620  2021-01-08 06:08:25.336946
# 3  1.128100e-06         2620  2021-01-08 06:08:25.336946
# 4  3.000000e-01         2620  2021-01-08 06:08:25.336946

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        testID assessmentItemID  difficultyLevel  discriminationLevel  \
# 0  A050000001       A050001001        -0.697606            35.359981
# 1  A050000001       A050001002        -1.280910            39.087825
# 2  A050000001       A050001003         0.016911             2.258198
# 3  A050000001       A050001004        -0.186766             1.947567
# 4  A050000001       A050001005         0.402467             4.070137
# 5  A050000001       A050001006         0.020605            38.360888
# 6  A050000001       A050001007        -0.491218             1.725699
#
#      guessLevel knowledgeTag                   Timestamp
# 0  1.147400e-06         2620  2021-01-08 06:08:25.336946
# 1  3.631640e-02         2620  2021-01-08 06:08:25.336946
# 2  7.119000e-07         2620  2021-01-08 06:08:25.336946
# 3  1.128100e-06         2620  2021-01-08 06:08:25.336946
# 4  3.000000e-01         2620  2021-01-08 06:08:25.336946
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   testID               7 non-null      object
#  1   assessmentItemID     7 non-null      object
#  2   difficultyLevel      7 non-null      float64
#  3   discriminationLevel  7 non-null      float64
#  4   guessLevel           7 non-null      float64
#  5   knowledgeTag         7 non-null      object
#  6   Timestamp            7 non-null      object
# dtypes: float64(3), object(4)
# memory usage: 520.0+ bytes

# %% [markdown]
# 7개 밖에 없음

# %% [markdown]
# zfill 함수는 자리수에 맞춰 0을 채워줌

# %%
"2".zfill(3)
# Out:
# '002'

# %%
path = 'C:/Users/klove/OneDrive/바탕 화면/학교 활동/창업동아리/mathdata/수학분야 학습자 역량 측정 데이터/Training/성취수준데이터셋_train/5학년/'

# %%
for i in range(193):
    print(str(i).zfill(3))
# Out:
# 000
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# ...

# %%
json_data2 = []
l2 = []
for i in range(1,194):
    p = path + "실력평가"+ str(i).zfill(3)+ "/2_문항IRT"
    try: #혹시나 없을까봐,,
        for j in os.listdir(p):
            with open(p+"/"+j, "r") as json_file:
                json_data2.append(json.load(json_file))
    except FileNotFoundError as e:
        print(e)

# %%
json_data2
# Out:
# [{'testID': 'A050000001',
#   'assessmentItemID': 'A050001001',
#   'difficultyLevel': -0.6976055076,
#   'discriminationLevel': 35.3599808524,
#   'guessLevel': 1.1474e-06,
#   'knowledgeTag': '2620',
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'testID': 'A050000001',
#   'assessmentItemID': 'A050001002',
#   'difficultyLevel': -1.280909903,
#   'discriminationLevel': 39.0878253094,
#   'guessLevel': 0.0363163975,
#   'knowledgeTag': '2620',
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'testID': 'A050000001',
#   'assessmentItemID': 'A050001003',
#   'difficultyLevel': 0.016911047,
#   'discriminationLevel': 2.2581983949,
#   'guessLevel': 7.119e-07,
#   'knowledgeTag': '2620',
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'testID': 'A050000001',
#   'assessmentItemID': 'A050001004',
#   'difficultyLevel': -0.186766277,
#   'discriminationLevel': 1.9475673915,
#   'guessLevel': 1.1281e-06,
#   'knowledgeTag': '2620',
# ...

# %%
df = pd.DataFrame(json_data2)

# %%
df
# Out:
#           testID assessmentItemID  difficultyLevel  discriminationLevel  \
# 0     A050000001       A050001001        -0.697606            35.359981
# 1     A050000001       A050001002        -1.280910            39.087825
# 2     A050000001       A050001003         0.016911             2.258198
# 3     A050000001       A050001004        -0.186766             1.947567
# 4     A050000001       A050001005         0.402467             4.070137
# ...          ...              ...              ...                  ...
# 1261  A050000192       A050192005        -1.727226             1.724574
# 1262  A050000193       A050193001        -0.878442             1.515791
# 1263  A050000193       A050193002        -1.631115             4.928855
# 1264  A050000193       A050193003         1.065869             1.185227
# 1265  A050000193       A050193004        -1.303081             2.629911
#
#         guessLevel knowledgeTag                   Timestamp
# ...

# %%
df.info() # 1266개의 정보가 있음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   testID               1266 non-null   object
#  1   assessmentItemID     1266 non-null   object
#  2   difficultyLevel      1266 non-null   float64
#  3   discriminationLevel  1266 non-null   float64
#  4   guessLevel           1266 non-null   float64
#  5   knowledgeTag         1266 non-null   object
#  6   Timestamp            1266 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 69.4+ KB

# %%
#문항변별도, 문항난이도, 문항추측도, 학습자 능력수준

# %%
test = df[['testID','assessmentItemID','difficultyLevel','discriminationLevel', 'guessLevel']]
test
# Out:
#           testID assessmentItemID  difficultyLevel  discriminationLevel  \
# 0     A050000001       A050001001        -0.697606            35.359981
# 1     A050000001       A050001002        -1.280910            39.087825
# 2     A050000001       A050001003         0.016911             2.258198
# 3     A050000001       A050001004        -0.186766             1.947567
# 4     A050000001       A050001005         0.402467             4.070137
# ...          ...              ...              ...                  ...
# 1261  A050000192       A050192005        -1.727226             1.724574
# 1262  A050000193       A050193001        -0.878442             1.515791
# 1263  A050000193       A050193002        -1.631115             4.928855
# 1264  A050000193       A050193003         1.065869             1.185227
# 1265  A050000193       A050193004        -1.303081             2.629911
#
#         guessLevel
# 0     1.147400e-06
# 1     3.631640e-02
# 2     7.119000e-07
# 3     1.128100e-06
# ...

# %%
json_datas = []
l2 = []
for i in range(1,194):
    p = path + "실력평가"+ str(i).zfill(3)+ "/3_응시자IRT"
    try:
        for j in os.listdir(p):
            with open(p+"/"+j, "r") as json_file:
                json_datas.append(json.load(json_file))

    except FileNotFoundError as e:
        print(e)

# %%
json_datas
# Out:
# [{'learnerID': 'A050000161',
#   'learnerProfile': 'F;S01;5',
#   'testID': 'A050000001',
#   'theta': 0.9134085618,
#   'realScore': 0.9456028823,
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'learnerID': 'A050000407',
#   'learnerProfile': 'M;S01;5',
#   'testID': 'A050000001',
#   'theta': 0.11613609,
#   'realScore': 0.7689834818,
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'learnerID': 'A050000868',
#   'learnerProfile': 'M;S01;5',
#   'testID': 'A050000001',
#   'theta': 0.9134085618,
#   'realScore': 0.9456028823,
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'learnerID': 'A050001406',
#   'learnerProfile': 'M;S01;5',
#   'testID': 'A050000001',
#   'theta': -0.7655478534,
#   'realScore': 0.3196537348,
#   'Timestamp': '2021-01-08 06:08:25.336946'},
#  {'learnerID': 'A050001536',
#   'learnerProfile': 'M;S01;5',
#   'testID': 'A050000001',
#   'theta': -1.0218542912,
#   'realScore': 0.2734123289,
#   'Timestamp': '2021-01-08 06:08:25.336946'},
# ...

# %%
people_df = pd.DataFrame(json_datas)
people_df
# Out:
#         learnerID learnerProfile      testID     theta  realScore  \
# 0      A050000161        F;S01;5  A050000001  0.913409   0.945603
# 1      A050000407        M;S01;5  A050000001  0.116136   0.768983
# 2      A050000868        M;S01;5  A050000001  0.913409   0.945603
# 3      A050001406        M;S01;5  A050000001 -0.765548   0.319654
# 4      A050001536        M;S01;5  A050000001 -1.021854   0.273412
# ...           ...            ...         ...       ...        ...
# 31596  A050002903        F;S01;5  A050000193 -0.462357   0.737220
# 31597  A050002907        F;S01;5  A050000193  0.528387   0.856988
# 31598  A050002909        M;S01;5  A050000193 -0.462357   0.737220
# 31599  A050002919        F;S01;5  A050000193 -0.626725   0.706388
# 31600  A050002927        M;S01;5  A050000193 -1.270024   0.518583
#
#                         Timestamp
# 0      2021-01-08 06:08:25.336946
# 1      2021-01-08 06:08:25.336946
# 2      2021-01-08 06:08:25.336946
# ...

# %%
people = people_df[['testID', 'realScore']]
people
# Out:
#            testID  realScore
# 0      A050000001   0.945603
# 1      A050000001   0.768983
# 2      A050000001   0.945603
# 3      A050000001   0.319654
# 4      A050000001   0.273412
# ...           ...        ...
# 31596  A050000193   0.737220
# 31597  A050000193   0.856988
# 31598  A050000193   0.737220
# 31599  A050000193   0.706388
# 31600  A050000193   0.518583
#
# [31601 rows x 2 columns]

# %%
merge_df = pd.merge(test, people, on='testID', how="outer")
merge_df
# Out:
#             testID  difficultyLevel  discriminationLevel  guessLevel  \
# 0       A050000001        -0.697606            35.359981    0.000001
# 1       A050000001        -0.697606            35.359981    0.000001
# 2       A050000001        -0.697606            35.359981    0.000001
# 3       A050000001        -0.697606            35.359981    0.000001
# 4       A050000001        -0.697606            35.359981    0.000001
# ...            ...              ...                  ...         ...
# 206957  A050000193        -1.303081             2.629911    0.000016
# 206958  A050000193        -1.303081             2.629911    0.000016
# 206959  A050000193        -1.303081             2.629911    0.000016
# 206960  A050000193        -1.303081             2.629911    0.000016
# 206961  A050000193        -1.303081             2.629911    0.000016
#
#         realScore
# 0        0.945603
# 1        0.768983
# 2        0.945603
# 3        0.319654
# 4        0.273412
# ...           ...
# ...

# %%
merge_df.isnull().values.any()
# Out:
# False

# %%
func1 = lambda t: np.array([t, 0.5 * t, 0])0
# Out:
#   File "<ipython-input-105-33f18c57fa72>", line 1
#     func1 = lambda t: np.array([t, 0.5 * t, 0])0
#                                                ^
# SyntaxError: invalid syntax

# %%
# p(&)  = c+ (1-c) * 1 %( 1+ math.exp(-1.7*a*(%-b)))

# %%
import matplotlib.pyplot as plt

print(merge_df['difficultyLevel'].values)
# Out:
# [-0.69760551 -0.69760551 -0.69760551 ... -1.30308122 -1.30308122
#  -1.30308122]

# %%
plt.plot(merge_df['difficultyLevel'].values)

# %%
plt.plot(merge_df['realScore'].values)

# %%
plt.plot(test['difficultyLevel'].values)

# %% [markdown]
# a = difficultyLevel 문항 난이도 Float 필수
#
# b = discriminationLevel 문항 변별도 Float 필수
#
# c = guessLevel 문항 추측도 Float 필수
#
# y = 학습자의 진점수

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = merge_df[['difficultyLevel']].values
a
# Out:
# array([[-0.69760551],
#        [-0.69760551],
#        [-0.69760551],
#        ...,
#        [-1.30308122],
#        [-1.30308122],
#        [-1.30308122]])

# %%
b = merge_df[['discriminationLevel']].values
b
# Out:
# array([[35.35998085],
#        [35.35998085],
#        [35.35998085],
#        ...,
#        [ 2.62991098],
#        [ 2.62991098],
#        [ 2.62991098]])

# %%
c = merge_df[['guessLevel']].values
c
# Out:
# array([[1.14740e-06],
#        [1.14740e-06],
#        [1.14740e-06],
#        ...,
#        [1.57738e-05],
#        [1.57738e-05],
#        [1.57738e-05]])

# %%
y = merge_df[['realScore']].values
y
# Out:
# array([[0.94560288],
#        [0.76898348],
#        [0.94560288],
#        ...,
#        [0.7372204 ],
#        [0.70638772],
#        [0.51858344]])

# %%
 
# 차트 종류, 제목, 차트 크기, 범례, 폰트 크기 설정
ax = merge_df.plot(kind='bar', title='IRT', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('difficultyLevel','guessLevel','discriminationLevel', fontsize=12)          # x축 정보 표시
ax.set_ylabel('realScore', fontsize=12)     # y축 정보 표시
ax.legend(['difficultyLevel','guessLevel','discriminationLevel', 'realScore'], fontsize=12)    # 범례 지정
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-95a7b53430ba> in <module>
#       1 # 차트 종류, 제목, 차트 크기, 범례, 폰트 크기 설정
#       2 ax = merge_df.plot(kind='bar', title='IRT', figsize=(12, 4), legend=True, fontsize=12)
# ----> 3 ax.set_xlabel('difficultyLevel','guessLevel','discriminationLevel', fontsize=12)          # x축 정보 표시
#       4 ax.set_ylabel('realScore', fontsize=12)     # y축 정보 표시
#       5 ax.legend(['difficultyLevel','guessLevel','discriminationLevel', 'realScore'], fontsize=12)    # 범례 지정
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ...

# %%
fig = plt.figure(figsize=(15,5))

# %%
import fractions # 분수
fractions.Fraction(4,16)
# Out:
# Fraction(1, 4)

# %%
import math 
from fractions import Fraction
x = [ci+(1-ci)* Fraction(1, 1+math.exp((-1.7)* ai*(yi-bi))) for ai,bi,ci,yi in zip(a,b,c,y)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-08243e2c681b> in <module>
#       1 import math
#       2 from fractions import Fraction
# ----> 3 x = [ci+(1-ci)* Fraction(1, 1+math.exp((-1.7)* ai*(yi-bi))) for ai,bi,ci,yi in zip(a,b,c,y)]
#
# <ipython-input-117-08243e2c681b> in <listcomp>(.0)
#       1 import math
#       2 from fractions import Fraction
# ----> 3 x = [ci+(1-ci)* Fraction(1, 1+math.exp((-1.7)* ai*(yi-bi))) for ai,bi,ci,yi in zip(a,b,c,y)]
#
# ~\anaconda3\lib\fractions.py in __new__(cls, numerator, denominator, _normalize)
#     172                 )
#     173         else:
# --> 174             raise TypeError("both arguments should be "
#     175                             "Rational instances")
#     176
#
# TypeError: both arguments should be Rational instances

# %%
plt.plot(a, y)

# %%
merge_df.corr()
# Out:
#                      difficultyLevel  discriminationLevel  guessLevel  \
# difficultyLevel             1.000000            -0.014276    0.237543
# discriminationLevel        -0.014276             1.000000    0.033879
# guessLevel                  0.237543             0.033879    1.000000
# realScore                  -0.227193             0.006740    0.046824
#
#                      realScore
# difficultyLevel      -0.227193
# discriminationLevel   0.006740
# guessLevel            0.046824
# realScore             1.000000

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
